# %% [markdown]
# # Finance Data Project-Bank of Canada

# %% [markdown]
# In this data project, I will focus on exploratory data analysis of stock price in four Banks of Canada. How four Banks,stock value change from and through the Covid-19 pandemic.

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # The Imports

# %%
from pandas_datareader import data, wb
import datetime as dt
import pandas as pd
from pandas_datareader import data as pdr
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#start and end date

end=dt.datetime.now()
start=dt.datetime(2019,12,31)
start,end
# Out:
# (datetime.datetime(2019, 12, 31, 0, 0),
#  datetime.datetime(2022, 11, 2, 22, 22, 10, 295149))

# %% [markdown]
# # I got stock information from Yahoo finance for the following Banks:
#
#     Scotia Bank
#     TD Canada Bank
#     Royal Bank of Canada
#     Bank of Montreal

# %%
#Scotia Bank
BNS=data.DataReader("BNS",'yahoo',start,end)

# %%
BNS
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2019-12-31  56.560001  56.209999  56.270000  56.490002   623300.0  48.120480
# 2020-01-02  56.779999  56.509998  56.599998  56.720001   738100.0  48.316402
# 2020-01-03  56.730000  56.290001  56.380001  56.650002   794100.0  48.256775
# 2020-01-06  55.950001  55.540001  55.860001  55.860001  1310200.0  48.172260
# 2020-01-07  55.599998  55.049999  55.560001  55.200001  1425700.0  47.603096
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-27  48.810001  48.330002  48.529999  48.480000  3210400.0  48.480000
# 2022-10-28  48.930000  48.389999  48.459999  48.639999  2601800.0  48.639999
# 2022-10-31  48.750000  48.250000  48.490002  48.320000  3502700.0  48.320000
# 2022-11-01  49.110001  47.980000  49.009998  48.410000  2007100.0  48.410000
# 2022-11-02  49.060001  47.740002  48.450001  47.810001  1931400.0  47.810001
#
# [717 rows x 6 columns]

# %%
#Royal Bank
RY=data.DataReader("BNS",'yahoo',start,end)

# %%
RY
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2019-12-31  56.560001  56.209999  56.270000  56.490002   623300.0  48.120480
# 2020-01-02  56.779999  56.509998  56.599998  56.720001   738100.0  48.316402
# 2020-01-03  56.730000  56.290001  56.380001  56.650002   794100.0  48.256771
# 2020-01-06  55.950001  55.540001  55.860001  55.860001  1310200.0  48.172264
# 2020-01-07  55.599998  55.049999  55.560001  55.200001  1425700.0  47.603096
# ...               ...        ...        ...        ...        ...        ...
# 2022-10-27  48.810001  48.330002  48.529999  48.480000  3210400.0  48.480000
# 2022-10-28  48.930000  48.389999  48.459999  48.639999  2601800.0  48.639999
# 2022-10-31  48.750000  48.250000  48.490002  48.320000  3502700.0  48.320000
# 2022-11-01  49.110001  47.980000  49.009998  48.410000  2007100.0  48.410000
# 2022-11-02  49.060001  47.740002  48.450001  47.810001  1931400.0  47.810001
#
# [717 rows x 6 columns]

# %%
tickers=['BNS','TD','RY','BMO']
ticks=[i+'.TO' for i in tickers]
ticks
# Out:
# ['BNS.TO', 'TD.TO', 'RY.TO', 'BMO.TO']

# %%
tickers
# Out:
# ['BNS', 'TD', 'RY', 'BMO']

# %%
bank_stocks=pdr.DataReader(tickers,'yahoo',start,end)
bank_stocks.head()
# Out:
# Attributes  Adj Close                                       Close             \
# Symbols           BNS         TD         RY        BMO        BNS         TD
# Date
# 2019-12-31  48.120480  49.456589  70.286835  68.140884  56.490002  56.130001
# 2020-01-02  48.316402  49.817844  70.730560  68.263969  56.720001  56.540001
# 2020-01-03  48.256767  49.773788  70.482071  68.096901  56.650002  56.490002
# 2020-01-06  48.172264  49.870701  70.632950  68.158447  55.860001  56.599998
# 2020-01-07  47.603100  49.641621  70.437714  67.824356  55.200001  56.340000
#
# Attributes                             High             ...        Low  \
# Symbols            RY        BMO        BNS         TD  ...         RY
# Date                                                    ...
# 2019-12-31  79.199997  77.500000  56.560001  56.220001  ...  78.930000
# 2020-01-02  79.699997  77.639999  56.779999  56.570000  ...  79.180000
# 2020-01-03  79.419998  77.449997  56.730000  56.509998  ...  79.029999
# ...

# %%
bank_stocks.index
# Out:
# DatetimeIndex(['2019-12-31', '2020-01-02', '2020-01-03', '2020-01-06',
#                '2020-01-07', '2020-01-08', '2020-01-09', '2020-01-10',
#                '2020-01-13', '2020-01-14',
#                ...
#                '2022-10-20', '2022-10-21', '2022-10-24', '2022-10-25',
#                '2022-10-26', '2022-10-27', '2022-10-28', '2022-10-31',
#                '2022-11-01', '2022-11-02'],
#               dtype='datetime64[ns]', name='Date', length=717, freq=None)

# %%
bank_stocks.columns
# Out:
# MultiIndex([('Adj Close', 'BNS'),
#             ('Adj Close',  'TD'),
#             ('Adj Close',  'RY'),
#             ('Adj Close', 'BMO'),
#             (    'Close', 'BNS'),
#             (    'Close',  'TD'),
#             (    'Close',  'RY'),
#             (    'Close', 'BMO'),
#             (     'High', 'BNS'),
#             (     'High',  'TD'),
#             (     'High',  'RY'),
#             (     'High', 'BMO'),
#             (      'Low', 'BNS'),
#             (      'Low',  'TD'),
#             (      'Low',  'RY'),
#             (      'Low', 'BMO'),
#             (     'Open', 'BNS'),
#             (     'Open',  'TD'),
#             (     'Open',  'RY'),
#             (     'Open', 'BMO'),
#             (   'Volume', 'BNS'),
#             (   'Volume',  'TD'),
#             (   'Volume',  'RY'),
#             (   'Volume', 'BMO')],
#            names=['Attributes', 'Symbols'])

# %%
bank_stocks.columns.names = ['Stock Info','Bank Ticker']

# %%
bank_stocks.head()
# Out:
# Stock Info   Adj Close                                       Close             \
# Bank Ticker        BNS         TD         RY        BMO        BNS         TD
# Date
# 2019-12-31   48.120480  49.456589  70.286835  68.140884  56.490002  56.130001
# 2020-01-02   48.316402  49.817844  70.730560  68.263969  56.720001  56.540001
# 2020-01-03   48.256767  49.773788  70.482071  68.096901  56.650002  56.490002
# 2020-01-06   48.172264  49.870701  70.632950  68.158447  55.860001  56.599998
# 2020-01-07   47.603100  49.641621  70.437714  67.824356  55.200001  56.340000
#
# Stock Info                              High             ...        Low  \
# Bank Ticker         RY        BMO        BNS         TD  ...         RY
# Date                                                     ...
# 2019-12-31   79.199997  77.500000  56.560001  56.220001  ...  78.930000
# 2020-01-02   79.699997  77.639999  56.779999  56.570000  ...  79.180000
# ...

# %% [markdown]
# # EDA

# %%
#what is the max close price for each bank:
bank_stocks.xs(key='Close',axis=1,level='Stock Info').max()
# Out:
# Bank Ticker
# BNS     74.580002
# TD      85.000000
# RY     118.790001
# BMO    122.339996
# dtype: float64

# %% [markdown]
# Return for each bank stock.
# Use pct_change() method

# %%
close=bank_stocks.Close
close.head()
# Out:
# Bank Ticker        BNS         TD         RY        BMO
# Date
# 2019-12-31   56.490002  56.130001  79.199997  77.500000
# 2020-01-02   56.720001  56.540001  79.699997  77.639999
# 2020-01-03   56.650002  56.490002  79.419998  77.449997
# 2020-01-06   55.860001  56.599998  79.589996  77.519997
# 2020-01-07   55.200001  56.340000  79.370003  77.139999

# %%
returns_stocks=close.pct_change()

# %%
returns_stocks
# Out:
# Bank Ticker       BNS        TD        RY       BMO
# Date
# 2019-12-31        NaN       NaN       NaN       NaN
# 2020-01-02   0.004072  0.007304  0.006313  0.001806
# 2020-01-03  -0.001234 -0.000884 -0.003513 -0.002447
# 2020-01-06  -0.013945  0.001947  0.002140  0.000904
# 2020-01-07  -0.011815 -0.004594 -0.002764 -0.004902
# ...               ...       ...       ...       ...
# 2022-10-27   0.006645  0.002180  0.003383  0.002905
# 2022-10-28   0.003300  0.001243  0.003263  0.007511
# 2022-10-31  -0.006579 -0.007137  0.002385 -0.019382
# 2022-11-01   0.001863  0.005938  0.000000 -0.001412
# 2022-11-02  -0.012394 -0.013360 -0.008111 -0.009135
#
# [717 rows x 4 columns]

# %%
import seaborn as sns
sns.pairplot(returns_stocks[1:])

# %%
returns_stocks.head()
# Out:
# Bank Ticker       BNS        TD        RY       BMO
# Date
# 2019-12-31        NaN       NaN       NaN       NaN
# 2020-01-02   0.004072  0.007304  0.006313  0.001806
# 2020-01-03  -0.001234 -0.000884 -0.003513 -0.002447
# 2020-01-06  -0.013945  0.001947  0.002140  0.000904
# 2020-01-07  -0.011815 -0.004594 -0.002764 -0.004902

# %% [markdown]
# Best and Worth single day returns for four banks:

# %%
#Worth single day
returns_stocks.idxmin()
# Out:
# Bank Ticker
# BNS   2020-03-12
# TD    2020-03-09
# RY    2020-03-12
# BMO   2020-03-12
# dtype: datetime64[ns]

# %%
#Best single day
returns_stocks.idxmax()
# Out:
# Bank Ticker
# BNS   2020-03-13
# TD    2020-03-13
# RY    2020-03-24
# BMO   2020-03-13
# dtype: datetime64[ns]

# %%
#Standard devision of the returns
returns_stocks.std()
#price of stocks are pretty steady for all banks because Standard devision is small during these years. 
#BMO is the riskiest
# Out:
# Bank Ticker
# BNS    0.019957
# TD     0.019847
# RY     0.017666
# BMO    0.021973
# dtype: float64

# %%
#returns std for 2020 year
returns_stocks['2020-01-01':'2020-12-31'].std()
# Out:
# Bank Ticker
# BNS    0.028776
# TD     0.028136
# RY     0.025045
# BMO    0.031787
# dtype: float64

# %%
sns.distplot(returns_stocks['2020-01-01':'2020-12-31']['BMO'],color='blue',bins=100)
# Out:
# C:\Users\Ansari\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='BMO', ylabel='Density'>

# %%
close=bank_stocks.Close
close.head()
# Out:
# Bank Ticker        BNS         TD         RY        BMO
# Date
# 2019-12-31   56.490002  56.130001  79.199997  77.500000
# 2020-01-02   56.720001  56.540001  79.699997  77.639999
# 2020-01-03   56.650002  56.490002  79.419998  77.449997
# 2020-01-06   55.860001  56.599998  79.589996  77.519997
# 2020-01-07   55.200001  56.340000  79.370003  77.139999

# %%
#describe close data:
close[close.index> end-dt.timedelta(days=365)].describe(percentiles=[0.1,0.5,0.9])
# Out:
# Bank Ticker         BNS          TD          RY         BMO
# count        252.000000  252.000000  252.000000  252.000000
# mean          63.587778   71.914484  102.185238  104.996270
# std            7.961118    6.897859    7.654118    9.531953
# min           46.290001   58.529999   85.510002   83.260002
# 10%           49.040001   63.217001   92.034002   91.932000
# 50%           65.215000   73.190002  101.154999  105.955002
# 90%           73.062000   81.269997  112.837997  117.102000
# max           74.580002   85.000000  118.790001  122.339996

# %%
#pair plot for four banks
import seaborn as sns
sns.pairplot(data=close)

# %%
close.plot(figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#import plotly for better visualization

import plotly.offline as pyo
pyo.init_notebook_mode(connected=True)

pd.options.plotting.backend='plotly'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
close.plot()
# Out:
# <div>                            <div id="11aab216-206f-4e05-8d02-c11180bf6217" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("11aab216-206f-4e05-8d02-c11180bf6217")) {                    Plotly.newPlot(                        "11aab216-206f-4e05-8d02-c11180bf6217",                        [{"hovertemplate":"Bank Ticker=BNS<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"BNS","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"BNS","showlegend":true,"x":["2019-12-31T00:00:00","2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-
# ...

# %%
# histogram plot for Royal Bank of Canada
close['RY'].pct_change().plot(kind='hist')
# Out:
# <div>                            <div id="5549b72f-718f-4c5a-8337-e793d1a820ba" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5549b72f-718f-4c5a-8337-e793d1a820ba")) {                    Plotly.newPlot(                        "5549b72f-718f-4c5a-8337-e793d1a820ba",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"variable=RY<br>value=%{x}<br>count=%{y}<extra></extra>","legendgroup":"RY","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"RY","offsetgroup":"RY","orientation":"v","showlegend":true,"x":[null,0.006313131556390683,-0.003513159222310991,0.00214049575503239,-0.002764085958424145,0.0060475710083018885,-0.00012526157071512944,0.00012527726314193188,0.004758984221341578,0.002866704697940037,0.00310713
# ...

# %% [markdown]
# # Moving Average

# %%
bank_stocks['Close']['TD']['2020'].plot()
# Out:
# <div>                            <div id="37e97b5e-43cb-47c1-8f9e-2e09d31f651e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37e97b5e-43cb-47c1-8f9e-2e09d31f651e")) {                    Plotly.newPlot(                        "37e97b5e-43cb-47c1-8f9e-2e09d31f651e",                        [{"hovertemplate":"variable=TD<br>Date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"TD","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"TD","orientation":"v","showlegend":true,"x":["2020-01-02T00:00:00","2020-01-03T00:00:00","2020-01-06T00:00:00","2020-01-07T00:00:00","2020-01-08T00:00:00","2020-01-09T00:00:00","2020-01-10T00:00:00","2020-01-13T00:00:00","2020-01-14T00:00:00","2020-01-15T00:00:00","2020-01-16T00:0
# ...

# %%
#Moving average for TD rolling 30 days average against the close price for these two banks for the year of 2020.
fig=plt.figure(figsize=(12,4))
ax = fig.add_axes([0,0,1,1])

ax.plot(bank_stocks['Close']['TD']['2020'].rolling(window=30).mean(), label="30 Days Average")
ax.plot(bank_stocks['Close']['TD']['2020'], label="RY Close")


ax.legend()
#Put a legend to the right of the plot
ax.legend(loc='center left', bbox_to_anchor=(1, 0.75))

# %%
#Moving average for RY rolling 30 days average against the close price for these two banks for the year of 2020.
fig=plt.figure(figsize=(12,4))
ax = fig.add_axes([0,0,1,1])

ax.plot(bank_stocks['Close']['RY']['2020'].rolling(window=30).mean(), label="30 Days Average")
ax.plot(bank_stocks['Close']['RY']['2020'], label="RY Close")


ax.legend()
#Put a legend to the right of the plot
ax.legend(loc='center left', bbox_to_anchor=(1, 0.75))

# %%
#Create a heatmap of the correlation between the stocks Close Price

sns.heatmap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True,cmap='magma',linecolor='white',linewidths=1)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
# Create a clustermap of the correlation between the stocks Close Price

sns.clustermap(bank_stocks.xs(key='Close',axis=1,level='Stock Info').corr(),annot=True,cmap='magma',linecolor='white',linewidths=1)

# %%
df2=RY[['High','Low','Open','Close']]['2020']
df2
# Out:
# C:\Users\Ansari\AppData\Local\Temp\ipykernel_11724\1348867993.py:1: FutureWarning:
#
# Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#                  High        Low       Open      Close
# Date
# 2020-01-02  56.779999  56.509998  56.599998  56.720001
# 2020-01-03  56.730000  56.290001  56.380001  56.650002
# 2020-01-06  55.950001  55.540001  55.860001  55.860001
# 2020-01-07  55.599998  55.049999  55.560001  55.200001
# 2020-01-08  55.930000  55.169998  55.169998  55.549999
# ...               ...        ...        ...        ...
# 2020-12-24  53.529999  53.169998  53.529999  53.490002
# 2020-12-28  54.099998  53.480000  53.779999  53.540001
# 2020-12-29  53.900002  53.540001  53.770000  53.630001
# 2020-12-30  54.220001  53.790001  53.880001  53.910000
# 2020-12-31  54.389999  53.959999  54.009998  54.040001
#
# ...

# %%
df2.plot(kind='box')
# Out:
# <div>                            <div id="978c1d1a-8770-415a-8d29-0087e3fe152a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("978c1d1a-8770-415a-8d29-0087e3fe152a")) {                    Plotly.newPlot(                        "978c1d1a-8770-415a-8d29-0087e3fe152a",                        [{"alignmentgroup":"True","hovertemplate":"variable=%{x}<br>value=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High","High
# ...
